# %%
# Un vendedor recibe un sueldo base más un 10% extra por
# comisión de sus ventas, el vendedor desea saber cuánto
# dinero obtendrá por concepto de comisiones por las tres
# ventas que realiza en el mes y el total que recibirá en
# el mes tomando en cuenta su sueldo base y comisiones.

def  sueldototal():
  sueldo = float(input("ingresa sueldo basico "))
  venta1 = float(input("ingresa venta 1 : "))
  venta2= float(input("ingresa venta 2: "))
  venta3 = float(input("ingresa venta 3: "))
  comi = ((venta1+venta2+venta3)* 0.10)
  print(f"la comision de las 3 ventas es de = {comi}")
  total = (sueldo+ comi)
  print(f"sueldo total y comision es = {total}")
sueldototal()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-9b44e257af16> in <cell line: 16>()
#      14   total = (sueldo+ comi)
#      15   print(f"sueldo total y comision es = {total}")
# ---> 16 sueldototal()
#
# <ipython-input-5-9b44e257af16> in sueldototal()
#       6
#       7 def  sueldototal():
# ----> 8   sueldo = float(input("ingresa sueldo basico "))
#       9   venta1 = float(input("ingresa venta 1 : "))
#      10   venta2= float(input("ingresa venta 2: "))
#
# /usr/local/lib/python3.9/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     849                 "raw_input was called, but this frontend does not support input requests."
#     850             )
# --> 851         return self._input_request(str(prompt),
#     852             self._parent_ident,
#     853             self._parent_header,
#
# /usr/local/lib/python3.9/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     893             except KeyboardInterrupt:
#     894                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 895                 raise KeyboardInterrupt("Interrupted by user") from None
#     896             except Exception as e:
#     897                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
#Un alumno desea saber cuál será su calificación final en
#la materia de Algoritmos. Dicha calificación se compone
#de tres exámenes parciales.

def calificacion():
  nota1 = float(input("Digite la calificación 1: "))
  nota2 = float(input("Digite la calificación 2: "))
  nota3 = float(input("Digite la calificación 3: "))
  calificacion = round((nota1 + nota2 + nota3) / 3 , 2)
  print(f"su calificacion final es de = {calificacion}")
calificacion()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-ff7e00417230> in <cell line: 11>()
#       9   calificacion = round((nota1 + nota2 + nota3) / 3 , 2)
#      10   print(f"su calificacion final es de = {calificacion}")
# ---> 11 calificacion()
#      12
#
# <ipython-input-8-ff7e00417230> in calificacion()
#       4
#       5 def calificacion():
# ----> 6   nota1 = float(input("Digite la calificación 1: "))
#       7   nota2 = float(input("Digite la calificación 2: "))
#       8   nota3 = float(input("Digite la calificación 3: "))
#
# /usr/local/lib/python3.9/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     849                 "raw_input was called, but this frontend does not support input requests."
#     850             )
# --> 851         return self._input_request(str(prompt),
#     852             self._parent_ident,
#     853             self._parent_header,
#
# /usr/local/lib/python3.9/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     893             except KeyboardInterrupt:
#     894                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 895                 raise KeyboardInterrupt("Interrupted by user") from None
#     896             except Exception as e:
#     897                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
# Una tienda ofrece un descuento del 15% sobre el total
# de la compra y un cliente desea saber cuánto deberá
# pagar finalmente por su compra.

def valort():
  valor = float(input("ingresa el total de la compra "))
  descuento = valor * 0.15
  total = valor - descuento

  print(f"el descuento aplicado a la compra es = {descuento}")
  print(f"el total de su copra es = {total}")
valort()

# %%
# Un maestro desea saber qué porcentaje de hombres y que
#porcentaje de mujeres hay en un grupo de estudiantes.
def porcentajt():
  mujeres = float(input("ingresa el total de mujeres "))
  hombres = float(input("ingresa el total de hombres "))

  totalM = mujeres / (mujeres+ hombres) * 100 ,"%"
  totalH = hombres / (mujeres+ hombres) * 100 ,"%"

  print(f"el total de mujeres en el salon es de = {totalM}")
  print(f"el total de hombres en el salon es de = {totalH}")
porcentajt()

# %%
#Si el empleado es mayor de 55 años disfrutará de un bono de prepensión correspondiente al 5% de su sueldo básico.
def bonot():
  edad = int(input("Ingrese la edad del empleado: "))
  sueldo = int(input("Ingrese el sueldo del empleado: "))
  if edad > 55:
    bono = sueldo *  0.05
    print("El empleado tiene derecho a un bono de prepensión de", bono)
  else:
    print("El empleado no tiene derecho a bono de prepensión")
bonot()
# Out:
# Ingrese la edad del empleado: 60
# Ingrese el sueldo del empleado: 1222
# El empleado tiene derecho a un bono de prepensión de 61.1

# %%
#Si el empleado es casado y tiene hijos se le otorgará un paseo cada diciembre
def paseo():

  estado_civil = input("¿Está casado? (sí o no): ").lower() == "si"
  tiene_hijos = input("¿Tiene hijos? (sí o no): ").lower() == "si"

  if estado_civil  and tiene_hijos:
    print("Se otorgará un paseo en diciembre")
  else:
    print("No es elegible para el paseo en diciembre")
paseo()
# Out:
# ¿Está casado? (sí o no): si
# ¿Tiene hijos? (sí o no): si
# Se otorgará un paseo en diciembre

# %%
#Si el sueldo básico está entre 1000000 y 1500000 tendrá una 
#comisión del 2% sobre el valor del sueldo; Si el sueldo básico 
#está entre 1500001 y 2000000 tendrá una comisión del 5% sobre 
#el valor del sueldo; para todos los demás casos no habrá comisión.
def sueldot():
  sueldobas = float(input("Ingrese el sueldo básico del empleado: "))
  comision = 0.0

  if sueldobas >= 1000000 and sueldobas<= 1500000:
    comision = 0.02
  elif sueldobas > 1500000 and sueldobas <= 2000000:
    comision = 0.05

  if comision > 0:
    valor_comision = sueldobas * comision
    print("La comisión correspondiente es de", valor_comision)
  else:
    print("No hay comisión")
sueldot()

# %%
#Si el empleado trabajó más de 20 días al mes y su sueldo es menor a 1000000 tendrá derecho a un bono de alimentación.
def totaldias():
  dias_trabajados = int(input("Ingrese el número de días trabajados del empleado: "))
  sueldo = int(input("Ingrese el sueldo del empleado: "))

  if dias_trabajados > 20 and sueldo < 1000000:
    bono_alimentacion = "si"
    
    print("El empleado tiene derecho a un bono de alimentación")
  else:
  print("El empleado no tiene derecho a bono de alimentación")
totaldias()
